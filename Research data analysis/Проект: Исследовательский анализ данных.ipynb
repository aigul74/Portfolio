# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Откройте-файл-с-данными-и-изучите-общую-информацию." data-toc-modified-id="Откройте-файл-с-данными-и-изучите-общую-информацию.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Откройте файл с данными и изучите общую информацию.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Поиск-и-замена-пропусков" data-toc-modified-id="Поиск-и-замена-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Поиск и замена пропусков</a></span></li><li><span><a href="#Изменение-типа-данных" data-toc-modified-id="Изменение-типа-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение типа данных</a></span></li><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li><li><span><a href="#Поиск-и-исключение-аномалий" data-toc-modified-id="Поиск-и-исключение-аномалий-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Поиск и исключение аномалий</a></span><ul class="toc-item"><li><span><a href="#check-r.2.1" data-toc-modified-id="check-r.2.1-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>check r.2.1</a></span></li></ul></li></ul></li><li><span><a href="#Добавление-в-таблицу-новых-столбцов." data-toc-modified-id="Добавление-в-таблицу-новых-столбцов.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Добавление в таблицу новых столбцов.</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-каждого-параметра-данных." data-toc-modified-id="Изучение-каждого-параметра-данных.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение каждого параметра данных.</a></span></li><li><span><a href="#Изучение-параметра-как-быстро-продавались-квартиры(анализ-столбца-days_exposition)" data-toc-modified-id="Изучение-параметра-как-быстро-продавались-квартиры(анализ-столбца-days_exposition)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение параметра как быстро продавались квартиры(анализ столбца days_exposition)</a></span></li><li><span><a href="#Нахождение-факторов-влияющих-на-цену-недвижимости." data-toc-modified-id="Нахождение-факторов-влияющих-на-цену-недвижимости.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Нахождение факторов влияющих на цену недвижимости.</a></span></li><li><span><a href="#Нахождение-средней-цены-одного-квадратного-метра-в-10-населённых-пунктах" data-toc-modified-id="Нахождение-средней-цены-одного-квадратного-метра-в-10-населённых-пунктах-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Нахождение средней цены одного квадратного метра в 10 населённых пунктах</a></span></li><li><span><a href="#Расчет-средней-цены-каждого-километра-в-Санкт-Петербурге-и-влияние-стоимости-объектов-от-расстояния-до-центра-города." data-toc-modified-id="Расчет-средней-цены-каждого-километра-в-Санкт-Петербурге-и-влияние-стоимости-объектов-от-расстояния-до-центра-города.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Расчет средней цены каждого километра в Санкт-Петербурге и влияние стоимости объектов от расстояния до центра города.</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Бонус" data-toc-modified-id="Бонус-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Бонус</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Айгуль :)
#
# Спасибо за работу на проекте
#
# стоит поправить итоговый вывод
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны замечательно, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Айгуль :) Спасибо за все исправления
#
# Критические ❌ комментарии
#
# + вернуть пропуски в колонку о скорости продаж, не заполнять их нулями и учесть пропуски при дальнейшей фильтрации
# + пересчитать скорость продаж
# + перепроверить итоговый вывод
#
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Айгуль :) Спасибо за все исправления
#
# Критические ❌ комментарии
#
# + вернуть пропуски в колонку о скорости продаж
# + завершить фильтрацию редких значений в п. 2.4
# + пересчитать скорость продаж
# + подправить расчет коэф. корреляции  в п. 4.3
# + перепроверить итоговый вывод
#
# добавил подсказок и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %%
<div class="alert alert-info">
<font size="4", color = "black"><b>✍ Комментарий студента</b></font>
    <br /> 
    <font size="3", color = "black">
<br /> ... , вот мой вопрос ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Айгуль :) Спасибо, что прислала задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ## Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
from IPython.display import display
display(df.head()) 
df.info()
df.describe()
df.hist(figsize=(22, 22));
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# **Вывод:**
# * Всего в данных 23699 значений
# * Пропуски содержаться в 14 столбцах из 22
# * Типы данных некорректны
# * В данных присутствуют аномальные значения

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Поиск и замена пропусков

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
#Вывели значения в процентах количества пропусков в каждом столбце
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# total_images - 0%
# last_price - 0%
# total_area - 0%
# first_day_exposition - 0%
# rooms - 0%
# ceiling_height - 39%
# floors_total - 0%
# living_area - 8%
# floor - 0%
# is_apartment - 88%
# studio - 0%
# open_plan - 0%
# kitchen_area - 10%
# balcony - 49%
# locality_name - 0%
# airports_nearest - 23%
# cityCenters_nearest - 23%
# parks_around3000 - 23%
# parks_nearest - 66%
# ponds_around3000 - 23%
# ponds_nearest - 62%
# days_exposition - 13%

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind= 'barh', figsize=(19,6), rot = 0, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(df)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Пример
#
# Предлагается изучить к какому нас. пункту относится основная масса пропусков в параметре 'airports_nearest', после взгляда на таблицу все становится ясно, что делать дальше с пропусками ...
#
#
#         # check
#         (
#             data[data['airports_nearest'].isna()]
#                     .value_counts('locality_name')).head(25).to_frame().rename(columns = {0:'count_gap'}
#         )
#
# У Питера из 15 тыс. записей, всего 84 пропуска в этом столбце ...

# %%
#создали таблицу с пропусками в параметре расстояние до аэропорта по населеным пунктам
data = df.copy()

x = (
        data
         .value_counts('locality_name')
         
         .to_frame()
         .rename(columns = {0:'count_loc'})
    )



y = (
        data[data['airports_nearest'].isna()]
                .value_counts('locality_name')).to_frame().rename(columns = {0:'count_gap'}
    )

z = x.join(y, how = 'outer').reset_index().sort_values(by = 'count_loc', ascending = False).head(25)
z.style.format("{:,.0f}", subset = ['count_gap', 'count_loc'])
# Out:
# <style  type="text/css" >
# </style><table id="T_22941_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >locality_name</th>        <th class="col_heading level0 col1" >count_loc</th>        <th class="col_heading level0 col2" >count_gap</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22941_level0_row0" class="row_heading level0 row0" >33</th>
#                         <td id="T_22941_row0_col0" class="data row0 col0" >Санкт-Петербург</td>
#                         <td id="T_22941_row0_col1" class="data row0 col1" >15,721</td>
#                         <td id="T_22941_row0_col2" class="data row0 col2" >85</td>
#             </tr>
#             <tr>
#                         <th id="T_22941_level0_row1" class="row_heading level0 row1" >291</th>
#                         <td id="T_22941_row1_col0" class="data row1 col0" >посёлок Мурино</td>
# ...

# %%
#удалаем пропуски в значениях столбцов название населенного пункта и всего этажей
df.dropna(subset=['locality_name', 'floors_total'], inplace=True)
#заменили пропуски значении количество балконов, парки в радиусе,водоемы в радиусе на 0
df[['balcony', 'parks_around3000', 'ponds_around3000']] = df[['balcony', \
'parks_around3000', 'ponds_around3000']].fillna(value=0)
#вывели количество не пустых значений столбца апартаменты
df['is_apartment'].sum()
#заменили пустые значения на False
df['is_apartment'] = df['is_apartment'].fillna(value=False)
#заменили пропуски значении расстояние до аэропорта, парка и водоема на 0
df[[ 'airports_nearest', 'ponds_nearest', 'parks_nearest']] = df[['airports_nearest', \
'ponds_nearest', 'parks_nearest']].fillna(0)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении медианой необходимо четко отслеживать изменение других статистик: среднее, дисперсию
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пропуски в ['days_exposition'] говорят нам, что квартиры еще не проданы..., неверно терять столь важный признак, → оставляем пропуски

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не изучено распределение пропусков по городам до заполнения значений в ['city_сenters_nearest']
#
# к каким населенным пунктам относятся и оценить степень влияния пропусков на дальнейший анализ (будут мешать или нет)

# %%
df.loc[df['cityCenters_nearest'].isna(), 'locality_name'].value_counts().to_frame()
# Out:
#                                 locality_name
# посёлок Мурино                            520
# Всеволожск                                398
# Гатчина                                   307
# деревня Кудрово                           299
# Выборг                                    237
# ...                                       ...
# деревня Новолисино                          1
# поселок Пчевжа                              1
# поселок Ромашки                             1
# деревня Пельгора                            1
# посёлок городского типа Рябово              1
#
# [345 rows x 1 columns]

# %%
#вывела диаграмму распределения пропусков по городам
df_city = df.loc[df['cityCenters_nearest'].isna()]['locality_name']
df_city.hist(bins = 150, figsize = (30,15), range = (10,150));

# %%
#Проверили пропуски
df.isna().sum().sort_values()
# Out:
# total_images               0
# ponds_around3000           0
# parks_nearest              0
# parks_around3000           0
# airports_nearest           0
# locality_name              0
# balcony                    0
# open_plan                  0
# ponds_nearest              0
# studio                     0
# floor                      0
# floors_total               0
# rooms                      0
# first_day_exposition       0
# total_area                 0
# last_price                 0
# is_apartment               0
# living_area             1865
# kitchen_area            2222
# days_exposition         3171
# cityCenters_nearest     5501
# ceiling_height          9084
# dtype: int64

# %% [markdown]
# ***Вывод:***
# - Удалили строки в которых много пропусков
# - Также удалили строки с пропусками населенных пунктов
# - Заменили остальные пропуски на медианные значения

# %% [markdown]
# ### Изменение типа данных

# %%
#изменили тип даных в столбце день публикации
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
#Поменяли тип данных значения общие этажи на целочисленный
df['floors_total'] = df['floors_total'].astype(int)
#Поменяли тип значения этаж к целочисленному типу
df['floor'] = df['floor'].astype(int)
#Поменяли тип значения количество парков в радиусе 3км. к целочисленному типу
df['parks_around3000'] = df['parks_around3000'].astype(int)
#Поменяли тип значения количество водоемов в радиусе 3км. к целочисленному типу
df['ponds_around3000'] = df['ponds_around3000'].astype(int)
#Поменяли тип значения цена к целочисленному типу
df['last_price'] = df['last_price'].astype(int)
#Поменяли тип значения балконы к целочисленному типу
df['balcony'] = df['balcony'].astype(int)
#df['days_exposition'] = df['days_exposition'].astype(int)
#Проверили типы данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        14481 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# **Вывод:**
# Изменили на тип int64 если числовые данные по логике не могут быть дробными
# first_day_exposition относиться к данным с датой поэтому поменяли на соответствующий тип
# Также is_apartment поменялось на булев тип после замены пропусков в столбце

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> тип данных изменен корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />цикл for скучает
#
#     df['floors_total'] = df['floors_total'].astype(int)
#     #Поменяли тип значения этаж к целочисленному типу
#     df['floor'] = df['floor'].astype(int)
#     #Поменяли тип значения количество парков в радиусе 3км. к целочисленному типу
#     df['parks_around3000'] = df['parks_around3000'].astype(int)
#     #Поменяли тип значения количество водоемов в радиусе 3км. к целочисленному типу
#     df['ponds_around3000'] = df['ponds_around3000'].astype(int)
#     #Поменяли тип значения цена к целочисленному типу
#     df['last_price'] = df['last_price'].astype(int)
#     #Поменяли тип значения балконы к целочисленному типу
#     df['balcony'] = df['balcony'].astype(int)
#     df['days_exposition'] = df['days_exposition'].astype(int)

# %% [markdown]
# ### Поиск дубликатов

# %%
#Поиск явных дубликатов
df.duplicated().sum()
# Out:
# 0

# %%
#Вывели отсортированный список уникальных названий для поиска неявных дубликатов
sorted(df['locality_name'].unique())
# Out:
# ['Бокситогорск',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Высоцк',
#  'Гатчина',
#  'Зеленогорск',
#  'Ивангород',
#  'Каменногорск',
#  'Кингисепп',
#  'Кириши',
#  'Кировск',
#  'Колпино',
#  'Коммунар',
#  'Красное Село',
#  'Кронштадт',
#  'Кудрово',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Луга',
#  'Любань',
#  'Мурино',
#  'Никольское',
#  'Новая Ладога',
#  'Отрадное',
#  'Павловск',
#  'Петергоф',
#  'Пикалёво',
#  'Подпорожье',
#  'Приморск',
#  'Приозерск',
#  'Пушкин',
#  'Санкт-Петербург',
#  'Светогорск',
#  'Сертолово',
#  'Сестрорецк',
#  'Сланцы',
#  'Сосновый Бор',
#  'Сясьстрой',
#  'Тихвин',
#  'Тосно',
#  'Шлиссельбург',
#  'городской поселок Большая Ижора',
#  'городской поселок Янино-1',
#  'городской посёлок Будогощь',
#  'городской посёлок Виллози',
#  'городской посёлок Лесогорский',
#  'городской посёлок Мга',
#  'городской посёлок Назия',
#  'городской посёлок Новоселье',
#  'городской посёлок Павлово',
#  'городской посёлок Рощино',
# ...

# %%
#заменили буквы в поселке и поселок городского типа для исправления дублирующихся названий населенных пунктов
df['locality_name'] = df['locality_name'].str.replace('ё', 'е')
to_replace = {r'(\b)городской поселок(\b)':r'\1поселок городского типа\2'}
df['locality_name'] = df['locality_name'].replace(to_replace, regex=True)
df['locality_name'] = df['locality_name'].replace('Кингисепп', 'поселок Кингисеппский')
df['locality_name'] = df['locality_name'].replace('Мурино', 'поселок Мурино')
df['locality_name'] = df['locality_name'].replace('Кудрово', 'деревня Кудрово')
df['locality_name'] = df['locality_name'].replace('деревня Калитино', 'поселок Калитино')
df['locality_name'] = df['locality_name'].replace('поселок Громово', 'поселок станции Громово')
df['locality_name'] = df['locality_name'].replace('садовое товарищество Рахья', 'поселок городского типа Рахья')
df['locality_name'] = df['locality_name'].replace('село Павлово', 'поселок городского типа Павлово')
df['locality_name'] = df['locality_name'].replace('поселок Рябово', 'поселок городского типа Рябово')
df['locality_name'] = df['locality_name'].replace('Красное Село', 'поселок Красносельское')
df['locality_name'] = df['locality_name'].replace('деревня Гарболово', 'поселок Гарболово')
df['locality_name'] = df['locality_name'].replace('деревня Щеглово', 'поселок Щеглово')
df['locality_name'] = df['locality_name'].replace('Любань', 'поселок Любань')
df['locality_name'] = df['locality_name'].replace('Никольское', 'село Никольское')
df['locality_name'] = df['locality_name'].replace('садовое товарищество Приладожский', 'поселок городского типа Приладожский')
df['locality_name'] = df['locality_name'].replace('поселок станции Приветнинское', 'поселок при железнодорожной станции Приветнинское')
df['locality_name'] = df['locality_name'].replace('поселок станции Вещево', 'поселок при железнодорожной станции Вещево')
df['locality_name'] = df['locality_name'].replace('поселок Лесное', 'коттеджный поселок Лесное')
df['locality_name'] = df['locality_name'].replace('Коммунар', 'поселок Коммунары')
df['locality_name'] = df['locality_name'].replace('деревня Зимитицы', 'поселок Зимитицы')

# %% [markdown]
# ***Вывод:***
# - Явные дубликаты в данных отсутствуют
# - Неявные в ручную изменили и привели к единому виду

# %%
# check
df['locality_name'].nunique()
# Out:
# 304

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# ### Поиск и исключение аномалий

# %%
#вывели количество строк в df
shape_first = df.shape[0]
print(shape_first)
# Out:
# 23565

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Создадим копию выборки до удаления

# %%
#  check
data = df.copy()

# %%
#вывела уникальные значения высоты потолка
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   3.2 ,   2.61,
#          3.25,   3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,
#          3.3 ,   2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,
#          3.4 ,   3.06,   2.72,   2.54,   2.51,   2.78,   2.76,  25.  ,
#          2.58,   3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,
#          2.45,   3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,
#          3.16,   3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,
#          5.  ,   2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,
#          2.83,   4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,
#          3.18,   3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,
#          2.63,   3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,
#          3.66,   3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,
# ...

# %%
#переименовала аномально высокие значения
data['ceiling_height'] = data['ceiling_height'].replace({
    20.0:2.0, 18.0:1.8, 27.5:2.75, 32.0:3.2, 27.0:2.7, 
    26.0:2.6, 22.6:2.26, 24:2.4, 25:2.5, 20.0:2.0
    })

# %%
#отфильтровала значения высоты потолка, также оставив пустые значения
data = data[(data['ceiling_height'].isna()) | ((data['ceiling_height'] >= 2.4) & (data['ceiling_height'] <= 4.5))]

# %%
#создала отсортированную таблицу со значение высоты потолка
data.ceiling_height.value_counts().to_frame()
# Out:
#       ceiling_height
# 2.50            3522
# 2.60            1646
# 2.70            1579
# 3.00            1108
# 2.80             988
# ...              ...
# 3.43               1
# 3.87               1
# 3.59               1
# 3.48               1
# 3.69               1
#
# [151 rows x 1 columns]

# %%
data.ceiling_height.hist(bins = 14, figsize = (15,10), range = (2,5));

# %%
#вывела процент удаления выбросов 
shape_second = data.shape[0]
print(shape_second)
print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 23522
# 0.2%

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    df[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_e0da2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0da2_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_e0da2_row0_col0" class="data row0 col0" >23,565.00</td>
#                         <td id="T_e0da2_row0_col1" class="data row0 col1" >23,565.00</td>
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос  Не понятно как по этой таблице можно обнаружить аномалии?...

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_d65c4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d65c4_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d65c4_row0_col0" class="data row0 col0" >23,522.00</td>
#                         <td id="T_d65c4_row0_col1" class="data row0 col1" >23,522.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, 4 записи со стоимостью квадратного метра выше 10 млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример ниже
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
#Вывела список уникальных значений
data['rooms'].unique()
# Out:
# array([ 3,  1,  2,  4,  5,  6,  0,  7, 11,  8, 14, 10, 15,  9, 19, 16, 12])

# %%
#вывела отсортированный список значенеий этажа
data.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    7990
# 2    7885
# 3    5770
# 4    1171
# 5     321
# 0     193
# 6     103
# 7      58
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
#отсортировали значение по количеству этажей
data = data[(data['rooms'] >= 0) & (data['rooms'] <= 7)]

# %%
#Визуализировали значения этажей после сортировки
data.rooms.hist(bins = 14, figsize = (15,5));

# %%
#Подсчет процента очистки от выбросов
shape_second = data.shape[0]
print(shape_second)
print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 23491
# 0.3%

# %%
#Вывели отсортированную таблицу с значением цены
data.last_price.value_counts().to_frame()
# Out:
#           last_price
# 4500000          341
# 3500000          289
# 4300000          260
# 4000000          260
# 4200000          258
# ...              ...
# 30750000           1
# 5748000            1
# 5535000            1
# 26391824           1
# 11615600           1
#
# [2907 rows x 1 columns]

# %%
#Вывели гистограмму значений цены с выбросами
data.last_price.hist(bins = 150, figsize = (15,5),range = (25000000, 35000000));

# %%
data.last_price.hist(bins = 150, figsize = (15,3), range = (8000000, 10000000));

# %%
#отсортировали и избавились от выбросов
data = data[(data['last_price'] >= 800000) & (data['last_price'] <= 28000000)]

# %%
#Подсчет процента очистки от выбросов
shape_second = data.shape[0]
print(shape_second)
print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 23032
# 2.3%

# %%
#создали гистограмму значения общая площадь
data.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры более двухсот квадратных метров можно считать редкостями
#
# особенно это заметно на втором графике, где мы подробно рассматриваем промежуток от 180 кв. метров до 500

# %%
#создали детальнюю гистограмму значения общая площадь
data.total_area.hist(bins = 150, figsize = (15,3), range = (160,500));

# %%
#отфильтровали, и очистили значение общей площади от выбросов
data = data[((data['total_area'] >= 23) & (data['total_area'] <= 160))]
#data = data[data['total_area'] <= 150]

# %%
#Подсчет процента очистки от выбросов
shape_second = data.shape[0]
print(shape_second)
print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 22736
# 3.5%

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось выполнить пункт 2.4 из брифа проекта
#
# __2.4.	Найдите и устраните редкие и выбивающиеся значения.__
#
# Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%

# %%
#вывели отсортированные занчения жилая площадь
data.living_area.value_counts().to_frame()
# Out:
#        living_area
# 18.00          869
# 17.00          660
# 30.00          590
# 20.00          475
# 16.00          468
# ...            ...
# 33.47            1
# 3.00             1
# 20.97            1
# 17.45            1
# 16.74            1
#
# [1535 rows x 1 columns]

# %%
#создали гистограмму значения жилая площадь
data.living_area.hist(bins = 150, figsize = (15,3));

# %%
#создали детальнюю гистограмму значения жилая площадь
data.living_area.hist(bins = 150, figsize = (15,3), range = (90,150));

# %%
data = data[(data['living_area'].isna()) | ((data['living_area'] >= 10) & (data['living_area'] <= 90))]

# %% [markdown]
# #### check r.2.1

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22581 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22581 non-null  int64
#  1   last_price            22581 non-null  int64
#  2   total_area            22581 non-null  float64
#  3   first_day_exposition  22581 non-null  datetime64[ns]
#  4   rooms                 22581 non-null  int64
#  5   ceiling_height        13851 non-null  float64
#  6   floors_total          22581 non-null  int64
#  7   living_area           20820 non-null  float64
#  8   floor                 22581 non-null  int64
#  9   is_apartment          22581 non-null  bool
#  10  studio                22581 non-null  bool
#  11  open_plan             22581 non-null  bool
#  12  kitchen_area          20518 non-null  float64
#  13  balcony               22581 non-null  int64
#  14  locality_name         22581 non-null  object
# ...

# %%
# check
data.shape
# Out:
# (22581, 22)

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#          7   living_area           21550 non-null  float64
#
#          data = data[data['living_area'] <= 120]
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Было 23391 записей, осталось 21429
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %%
#Подсчет процента очистки от выбросов
shape_second = data.shape[0]
print(shape_second)
print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 22581
# 4.2%

# %%
#вывели гистограмму площадь кухни
data.kitchen_area.hist(bins = 150, figsize = (15,3));

# %%
#вывели детальную гистограмму площадь кухни
data.kitchen_area.hist(bins = 150, figsize = (15,3), range = (0, 4.9));

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22581 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22581 non-null  int64
#  1   last_price            22581 non-null  int64
#  2   total_area            22581 non-null  float64
#  3   first_day_exposition  22581 non-null  datetime64[ns]
#  4   rooms                 22581 non-null  int64
#  5   ceiling_height        13851 non-null  float64
#  6   floors_total          22581 non-null  int64
#  7   living_area           20820 non-null  float64
#  8   floor                 22581 non-null  int64
#  9   is_apartment          22581 non-null  bool
#  10  studio                22581 non-null  bool
#  11  open_plan             22581 non-null  bool
#  12  kitchen_area          20518 non-null  float64
#  13  balcony               22581 non-null  int64
#  14  locality_name         22581 non-null  object
# ...

# %%
#отфильтровали значение площадь кухни
data = data[(data['kitchen_area'].isna()) | ((data['kitchen_area'] >= 4.9) & (data['kitchen_area'] <= 31))] #Вывели процент очистки от выбросов

# %%
# check
data.shape
# Out:
# (22328, 22)

# %%
#Вывели процент очистки от выбросов
shape_second = data.shape[0]
print(shape_second)
print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 22328
# 5.2%

# %%
data.days_exposition.hist(bins = 150, figsize = (15,3), range = (650,750));

# %%
data = data[(data['days_exposition'].isna()) | (data['days_exposition'] < 650)]

# %%
data.days_exposition.hist(bins = 150, figsize = (15,3), range = (250,650));

# %%
#Вывели процент очистки от выбросов
shape_second = data.shape[0]
print(shape_second)
print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 21413
# 9.1%

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.01, .5, .90, .9976])  
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4b34">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4b34_level0_col0" class="col_heading level0 col0" >rooms</th>
#       <th id="T_a4b34_level0_col1" class="col_heading level0 col1" >total_area</th>
#       <th id="T_a4b34_level0_col2" class="col_heading level0 col2" >ceiling_height</th>
#       <th id="T_a4b34_level0_col3" class="col_heading level0 col3" >days_exposition</th>
#       <th id="T_a4b34_level0_col4" class="col_heading level0 col4" >last_price</th>
#       <th id="T_a4b34_level0_col5" class="col_heading level0 col5" >living_area</th>
#       <th id="T_a4b34_level0_col6" class="col_heading level0 col6" >kitchen_area</th>
#       <th id="T_a4b34_level0_col7" class="col_heading level0 col7" >floor</th>
#       <th id="T_a4b34_level0_col8" class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
data.floors_total.value_counts().to_frame()
# Out:
#     floors_total
# 5           5229
# 9           3583
# 16          1285
# 12          1280
# 10          1077
# 4           1039
# 25          1019
# 17           788
# 6            710
# 3            574
# 14           520
# 18           465
# 7            464
# 24           437
# 15           338
# 23           323
# 2            308
# 19           304
# 8            294
# 22           268
# 20           239
# 13           200
# 11           176
# 27           157
# 21           143
# 26           121
# 35            24
# 28            20
# 1             20
# 36             3
# 34             1
# 60             1
# 29             1
# 33             1
# 52             1

# %%
data.floors_total.hist(bins = 20, figsize = (15,3), range = (0,2));

# %%
#Создаем срез значений 
data_list = ['floors_total']
for column in data_list:
    
    data = data[(data['floors_total'] >=2) & (data['floors_total'] <=27)]

# %%
#определили процент удаленных выбросов
shape_second = data.shape[0]
print(shape_second)


print('{:.1%}'.format((shape_first - shape_second) / shape_first))
# Out:
# 21341
# 9.4%

# %% [markdown]
# **Вывод:**
# - В значении высота потолка аномально большие данные изменили на близкие к действительности.
# - Процент выбросов составляет 9,4%.
# - После исключения выбросов, даные стали чище и достовернее.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f62bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f62bc_level0_col0" class="col_heading level0 col0" >rooms</th>
#       <th id="T_f62bc_level0_col1" class="col_heading level0 col1" >total_area</th>
#       <th id="T_f62bc_level0_col2" class="col_heading level0 col2" >ceiling_height</th>
#       <th id="T_f62bc_level0_col3" class="col_heading level0 col3" >days_exposition</th>
#       <th id="T_f62bc_level0_col4" class="col_heading level0 col4" >last_price</th>
#       <th id="T_f62bc_level0_col5" class="col_heading level0 col5" >living_area</th>
#       <th id="T_f62bc_level0_col6" class="col_heading level0 col6" >kitchen_area</th>
#       <th id="T_f62bc_level0_col7" class="col_heading level0 col7" >floor</th>
#       <th id="T_f62bc_level0_col8" class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости в колонках:
#
#         'total_area', 'days_exposition', 'last_price', 'living_area',  'kitchen_area'
#
# в некоторых минимально аномальные, в некоторых максимально аномальные

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 23-х квадратных метров можно считать редкостями
#
# особенно это заметно на графиках, где мы подробно рассматриваем промежуток до 25-ти кв.м.

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3), range = (10,33))
plt.ylim(0,60);

# %% [markdown]
# ## Добавление в таблицу новых столбцов.

# %%
#добавили новый столбец со значением цены 1 кв.метра
data['price_one_metr'] = data['last_price'] / data['total_area']
data['price_one_metr'] = data['price_one_metr'].astype(int)

# %%
#добавили новые столбцы с раздельными значениями по дате
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year

# %%
#Создали функцию для групировки и добавления в новый столбец значений по условию функции
def floor_group(x):
    try:
        if x['floor'] == 1:
            return 'первый'
        elif x['floor'] == x['floors_total']:
            return 'последний'
        else:
            return 'другой'
    except:
        pass
data['floor_type'] = data.apply(floor_group, axis=1)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %%
#Вывели данные
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000      108.00           2019-03-07      3
# 1              7     3350000       40.40           2018-12-04      1
# 2             10     5196000       56.00           2015-08-20      2
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 7              5     7915000       71.60           2019-04-18      2
# 8             20     2900000       33.16           2018-05-23      1
# 9             18     5400000       61.00           2017-02-26      3
# 10             5     5050000       39.60           2017-11-16      1
# 11             9     3300000       44.00           2018-08-27      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8         False  ...
# ...

# %%
#добавили новый столбец с отредактированным значением стольбца расстояние до центра
data['cityCenters_nearest_km'] = (data['cityCenters_nearest'] / 1000).apply(np.floor)
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000      108.00           2019-03-07      3
# 1              7     3350000       40.40           2018-12-04      1
# 2             10     5196000       56.00           2015-08-20      2
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 7              5     7915000       71.60           2019-04-18      2
# 8             20     2900000       33.16           2018-05-23      1
# 9             18     5400000       61.00           2017-02-26      3
# 10             5     5050000       39.60           2017-11-16      1
# 11             9     3300000       44.00           2018-08-27      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8         False  ...
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ***Вывод:***
# - Добавили новые столбцы со значениями которые будем в дальнейшем использовать
# - Сгруппировали этажи по типу для дальнейшего изучения зависимости от типа
# - Слишком разбросанные даные следует укрупнить для упрощения в выявлении зависимостей в данных

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение каждого параметра данных.

# %%
#Визуализировали общую площадь
plt.hist(data['total_area'], bins=10, range=(1,300))
plt.title('Площадь квартир')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по площади варианты:')
print(data['total_area'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по площади варианты:
# 4323     160.0
# 20918    160.0
# 8486     160.0
# 19519    160.0
# 5956     159.3
# 22076    159.0
# 17692    159.0
# 23555    158.5
# 15165    158.0
# 11607    158.0
# Name: total_area, dtype: float64

# %% [markdown]
# ***Вывод:***
# - Площадь квартир в основном менее 100 кв.метров
# - Больше всего квартир с площадью примерно от 30 до 60 кв.метров

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец
#
# можно добавить кол-во корзин к параметрам гистограммы

# %%
#Визуализировали жилую площадь
plt.hist(data['living_area'], bins=70, range=(10,80))
plt.title('Жилая площадь квартир')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по жилой площади варианты:')
print(data['living_area'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по жилой площади варианты:
# 1895     90.0
# 5397     90.0
# 13714    90.0
# 9597     90.0
# 12681    90.0
# 3485     90.0
# 14412    90.0
# 20260    90.0
# 17996    90.0
# 6269     90.0
# Name: living_area, dtype: float64

# %% [markdown]
# ***Вывод:***
# - Самые распространённые варианты с жилой площадью от 10 до 50 метров.
# - После 80 метров встречаются единичные случаи.
# - Два пика графика вызваны, вероятно, тем, что это жилые площади для 1-комнатной, затем для 2-комнатной и после этого для 3-комнатной квартиры.

# %%
#Визуализировали площадь кухни
plt.hist(data['kitchen_area'], bins=14, range=(0,20))
plt.title('Площадь кухни')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по площади кухни варианты:')
print(data['kitchen_area'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по площади кухни варианты:
# 576      31.00
# 9911     31.00
# 8566     31.00
# 9778     31.00
# 6523     31.00
# 11504    30.59
# 1671     30.20
# 13633    30.20
# 4780     30.00
# 15104    30.00
# Name: kitchen_area, dtype: float64

# %% [markdown]
# ***Вывод:***
# - Самые распространённые кухни - от 5 до 12.5 метров.
# - Больше 15 метров кухни практически не встречаются.
# - Меньше 4 метров - единичные случаи.
# - Кухни площадью 0 метров скорее всего совмещенные с гостинной(студии)

# %%
#Визуализировали стоимость квартир
plt.hist(data['last_price'], bins=25, range=(1000000,20000000))
plt.title('Стоимость квартир')
plt.xlabel('Стоимость')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по цене варианты:')
print(data.last_price.value_counts().to_frame().head(15))
# Out:
# Наибольшие по цене варианты:
#          last_price
# 4500000         333
# 3500000         274
# 4000000         253
# 4300000         250
# 3600000         249
# 4200000         249
# 3200000         230
# 3800000         226
# 3300000         223
# 3700000         221
# 4100000         219
# 3400000         215
# 5500000         215
# 3900000         212
# 3100000         211

# %% [markdown]
# ***Вывод:***
# - В основном стоимость квартир - от 2 до 6 миллионов.
# - Больше 10 миллионов вариантов мало и они выглядят очень странно и некоторые - на порядок дороже.

# %%
#Вывели гистограмму числа комнат
plt.hist(data['rooms'], bins=10, range=(1,6))
plt.title('Комнаты')
plt.xlabel('Количество комнат')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по числу комнат варианты:')
print(data['rooms'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по числу комнат варианты:
# 22264    7
# 23555    7
# 855      7
# 14603    7
# 15196    7
# 17991    7
# 9856     6
# 23047    6
# 3314     6
# 10763    6
# Name: rooms, dtype: int64

# %% [markdown]
# ***Вывод:***
# - В основном квартиры состоят из 1, 2 и 3 комнат.
# - Есть небольшая доля 4-комнатных квартир.
# - Варианты, где 5 комнат единичны.

# %%
#Вывели гистограмму с высотой потолков
plt.hist(data.query('(ceiling_height > 2) & (ceiling_height < 4)')['ceiling_height'], bins=20, range=(2.4, 3))
plt.title('Высота потолков')
plt.xlabel('Высота в метрах')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по высоте потолков варианты:')
print(data['ceiling_height'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по высоте потолков варианты:
# 3067     4.50
# 10159    4.50
# 6802     4.50
# 14519    4.50
# 2823     4.50
# 11651    4.40
# 4201     4.37
# 10754    4.30
# 17078    4.25
# 14619    4.20
# Name: ceiling_height, dtype: float64

# %% [markdown]
# ***Вывод:***
# - Большинство вариантов имеют высоту потолков от 2,5 до 2,8 метров.

# %%
#Визуализировали этаж квартир
plt.hist(data['floor'], bins=16, range=(1,27))
plt.title('Этажи')
plt.xlabel('Количество этажей')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по этажу варианты:')
print(data['floor'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по этажу варианты:
# 4091     27
# 23292    27
# 13276    27
# 113      27
# 6157     27
# 16644    27
# 2629     27
# 23428    26
# 22693    26
# 4724     26
# Name: floor, dtype: int64

# %%
#Визуализировали типы этажей
plt.hist(data['floor_type'], bins=5, range=(0,4))
plt.title('Этажи')
plt.xlabel('Количество типов этажей')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по этажу варианты:')
print(data['floor_type'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по этажу варианты:
# 14760    последний
# 3161     последний
# 13477    последний
# 3166     последний
# 13466    последний
# 13462    последний
# 13450    последний
# 13447    последний
# 3173     последний
# 3177     последний
# Name: floor_type, dtype: object

# %% [markdown]
# ***Вывод:***
# - Другой тип этажа преобладает по количеству
# - Первый и последний не популярные типы

# %%
#Визуализировали всего этажей
plt.hist(data['floor'], bins=16, range=(1,28))
plt.title('Этаж в доме')
plt.xlabel('Этаж')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по этажу варианты:')
print(data['floors_total'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по этажу варианты:
# 10890    27
# 7392     27
# 11555    27
# 13910    27
# 22631    27
# 11690    27
# 7187     27
# 1064     27
# 16214    27
# 17842    27
# Name: floors_total, dtype: int64

# %% [markdown]
# ***Вывод:***
# - Больше всего квартир продаются с 1 по 6 этажи.
# - Также 9 этаж пользуется спросом.
# - Дома выше 26 этажа практически не встречаются.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />пример гистограммы, изменен один параметр - кол-во корзин
#
# на которой четко видны пики - какой этажности дома наиболее распространены в выборке

# %%
# check

#Визуализировали всего этажей
plt.hist(data['floors_total'], bins=80, range=(1,40))
plt.title('Всего этажей в доме')
plt.xlabel('Количество этажей в доме')
plt.ylabel('Количество квартир');

# %% [markdown]
# ***Вывод:***
# - Большое количество квартир с этажностью 5 и 9 этажей.
# - Квартиры с этажностью 4, 9, 16, 25 примерно одинаковы по количеству +/- 1000.

# %%
#Визуализировали расстояние до центра города
plt.hist(data['cityCenters_nearest'], bins=14, range=(50,45000))
plt.title('Расстояние до центра города в метрах')
plt.xlabel('Расстояние в метрах')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по расстоянию варианты:')
print(data['cityCenters_nearest'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по расстоянию варианты:
# 5340     65952.0
# 577      65764.0
# 5218     64857.0
# 18884    62706.0
# 2974     62454.0
# 16569    61495.0
# 23123    60223.0
# 4441     59626.0
# 11244    59052.0
# 939      56745.0
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# ***Вывод:***
# - Квартиры в основном находяться на расстоянии от 10 до 20 км от центра города.
# - Также с 25 до 35 км идет небольшой всплеск, возможно загородная недвижимость или дальний пригород.

# %%
#Визуализировали расстояние до аэропорта
plt.hist(data['airports_nearest'], bins=14, range=(5000,70000))
plt.title('Расстояние до аэропорта')
plt.xlabel('Расстояние в метрах')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по расстоянию варианты:')
print(data['airports_nearest'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по расстоянию варианты:
# 5340     84853.0
# 577      84665.0
# 5218     83758.0
# 18884    81607.0
# 2974     81355.0
# 4441     78527.0
# 939      75646.0
# 376      73827.0
# 22941    73391.0
# 11244    72713.0
# Name: airports_nearest, dtype: float64

# %% [markdown]
# ***Вывод:***
# - В основном квартиры находяться  от аэропорта на расстояни от 10 до 50 км.
# - От 55 км количество падает, можно предположить что накладываеться и удаление от города.
# - Также ближе 10 км не популярный вариант для проживания.

# %%
#Визуализировали месяцы даты 
plt.hist(data['parks_nearest'], bins=14, range=(10,1000))
plt.title('Расстояние до парка')
plt.xlabel('Расстояние в метрах')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по расстоянию варианты:')
print(data['parks_nearest'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по расстоянию варианты:
# 19430    3190.0
# 10959    3190.0
# 1590     3064.0
# 23080    2984.0
# 2659     2905.0
# 1860     2888.0
# 7855     2880.0
# 3865     2847.0
# 22003    2768.0
# 7316     2747.0
# Name: parks_nearest, dtype: float64

# %% [markdown]
# ***Вывод:***
# - В основном все квартиры находятся до 500 метров от ближайшего парка.
# - Очень мало данных, большой процент нулевых значений после пребразованных пропусков.

# %%
#Визуализировали месяц публикации обьявления
plt.hist(data['month'], bins=12, range=(1,13))
plt.title('Месяц публикации обьявления')
plt.xlabel('Месяц')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по месяцу варианты:')
print(data.month.value_counts().to_frame())
# Out:
# Наибольшие по месяцу варианты:
#     month
# 2    2392
# 3    2304
# 11   2165
# 4    2159
# 10   1948
# 9    1793
# 8    1602
# 6    1578
# 7    1505
# 12   1438
# 1    1335
# 5    1122

# %% [markdown]
# ***Вывод:***
# - Меньше всего квартир выставляется на продажу в мае месяце.
# - Больше всего в феврале.

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы, сейчас может показаться, что в декабре публикуют самое большое кол-во объявлений

# %%
#Визуализировали день недели публикации обьявления
plt.hist(data['weekday'], bins=8, range=(0,8))
plt.title('День недели публикации обьявления')
plt.xlabel('Количество месяцев')
plt.ylabel('Количество квартир')
plt.show()
print('Наибольшие по дням недели варианты:')
print(data.weekday.value_counts().to_frame())
#print(data['weekday'].sort_values(ascending=False).head(10))
# Out:
# Наибольшие по дням недели варианты:
#    weekday
# 3     3818
# 1     3788
# 4     3661
# 2     3543
# 0     3249
# 5     1751
# 6     1531

# %% [markdown]
# ***Вывод:***
# - Меньше всего квартир выставляется в пятницу и субботу в воскресенье.
# - Максимальные количества обьявлении во вторник, четверг.

# %% [markdown]
# ### Изучение параметра как быстро продавались квартиры(анализ столбца days_exposition)

# %%
#
print('Время продажи (медиана):', round(data['days_exposition'].median()),'\n')
print('Время продажи (среднее):', round(data['days_exposition'].mean()),'\n')
# Гистограма времени продажи
plt.hist(data['days_exposition'], bins=100, range=(0,300))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()
# Изучаем значения срока продажи
data['days_exposition'].describe()
# Out:
# Время продажи (медиана): 89
#
# Время продажи (среднее): 142
# count    18462.000000
# mean       141.861824
# std        142.960241
# min          1.000000
# 25%         42.000000
# 50%         89.000000
# 75%        196.000000
# max        649.000000
# Name: days_exposition, dtype: float64

# %%
# Гистограма времени продажи детализация 45 дней
plt.hist(data['days_exposition'], bins=100, range=(0,45))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()

# %%
# Гистограма времени продажи детализация от 60 дней
plt.hist(data['days_exposition'], bins=100, range=(60,95))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()

# %%
plt.hist(data['days_exposition'], bins=100, range=(160,190))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# ***Вывод:***
# - Медианное время продажи - 88 дней.
# - Среднее время продажи - 141 день.
# - В основном квартиры продаются за срок в 150 дней.
# - Много квартир проданных сразу же в день выставления.
# - Есть большое число квартир, проданных всего за несколько дней после публикации.
# - А также есть варианты, которые продавались несколько десятков месяцев.
# - Быстрой продажей можно назвать срок в 22 дней и меньше.
# - Долгой продажей - 200 дней и дольше.
# - Всплеск продаж в 31, 61, 91 дни связан с тем что на 31-й день платного размещения
# включится автопродление.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи без нулевых заглушек - мы заполнили нулями более 3000 записей ...

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи после восстановления записей

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Можно посмотреть на изменение средней скорости продаж по годам

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %%
def days_exposition_price(x):
    try:
        if x['last_price'] < 4500000:
            return 45
        elif 4500000 <= x['last_price'] < 10000000:
            return 60
        else:
            return 90
    except:
        pass
data['exposition_price'] = data.apply(days_exposition_price, axis=1)

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 5            10     2890000        30.4           2018-09-10      1
# 6             6     3700000        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.7            16         51.0      8         False  ...
# 1             NaN            11         18.6      1         False  ...
# 2             NaN             5         34.3      4         False  ...
# 5             NaN            12         14.4      5         False  ...
# 6             NaN            26         10.6      6         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  price_one_metr weekday  \
# ...

# %%
plt.hist(data['exposition_price'], bins=14, range=(40,100))
plt.title('Время продажи по цене')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()
# Изучаем значения срока продажи
data['exposition_price'].describe()
# Out:
# count    21341.000000
# mean        55.212033
# std         12.650992
# min         45.000000
# 25%         45.000000
# 50%         60.000000
# 75%         60.000000
# max         90.000000
# Name: exposition_price, dtype: float64

# %% [markdown]
# ***Вывод:***
# - Быстрее всего продаються квартиры стоимостью до 4,5 млн. рублей.
# - Дольше всего продаются дорогие и очень дорогие квартиры.

# %% [markdown]
# ### Нахождение факторов влияющих на цену недвижимости.

# %%
data.corr()#находим коореляцию данных
# Out:
# /tmp/ipykernel_1588/2615964020.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()#находим коореляцию данных
#                         total_images  last_price  total_area     rooms  \
# total_images                1.000000    0.159115    0.117742  0.091567
# last_price                  0.159115    1.000000    0.752401  0.453354
# total_area                  0.117742    0.752401    1.000000  0.790910
# rooms                       0.091567    0.453354    0.790910  1.000000
# ceiling_height              0.031478    0.484904    0.414220  0.175240
# floors_total                0.013386    0.114691   -0.032497 -0.226340
# living_area                 0.106636    0.633764    0.920182  0.883228
# floor                       0.031642    0.091763   -0.026795 -0.166531
# ...

# %%
# Зависимость цены от этажа
(
    data.pivot_table(index='floor_type', values='last_price', aggfunc='median')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# %% [markdown]
# ***Вывод***:
# - Самые не популярный или дешевый этаж первый.
# - Самые высокие продажи или дорогие квартиры кроме первый и последний этажи.

# %%
df_cor = pd.DataFrame(data, columns=['last_price','total_area',])
df_cor.corr().round(3)
# Out:
#             last_price  total_area
# last_price       1.000       0.752
# total_area       0.752       1.000

# %%
var = 'total_area'
data_vr = pd.concat([data['last_price'], data[var]], axis=1)
data_vr.plot.scatter(x=var, y='last_price', ylim=(500000, 26000000))
plt.title('Диаграмма рассеяния — Общая площадь — цена');

# %%
df_cor = pd.DataFrame(data, columns=['last_price','living_area',])
df_cor.corr().round(3)
# Out:
#              last_price  living_area
# last_price        1.000        0.634
# living_area       0.634        1.000

# %%
var = 'living_area'
data_vr = pd.concat([data['last_price'], data[var]], axis=1)
data_vr.plot.scatter(x=var, y='last_price', ylim=(500000, 26000000))
plt.title('Диаграмма рассеяния — Жилая площадь — цена');

# %%
df_cor = pd.DataFrame(data, columns=['last_price','kitchen_area'])
df_cor.corr().round(3)
# Out:
#               last_price  kitchen_area
# last_price         1.000         0.553
# kitchen_area       0.553         1.000

# %%
var = 'kitchen_area'
data_vr = pd.concat([data['last_price'], data[var]], axis=1)
data_vr.plot.scatter(x=var, y='last_price', ylim=(500000, 26000000));
plt.title('Диаграмма рассеяния — Площадь кухни — цена')
# Out:
# Text(0.5, 1.0, 'Диаграмма рассеяния — Площадь кухни — цена')

# %%
df_cor = pd.DataFrame(data, columns=['last_price','rooms'])
df_cor.corr().round(3)
# Out:
#             last_price  rooms
# last_price       1.000  0.453
# rooms            0.453  1.000

# %%
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='kitchen_area', alpha=0.5, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
data[data['rooms'] == 2].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена двушки')


data[data['rooms'] == 2].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена двушки');

data[data['rooms'] == 2].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='kitchen_area', alpha=0.5, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена двушки')
# Out:
# Text(0.5, 1.0, 'Диаграмма рассеяния — Общая площадь — цена двушки')

# %%
# импорт библиотеки
import seaborn as sns

# %%
# 
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# ***Вывод:***
# - Цена недвижимости коррелирует с общей площадью, жилой площадью и площадью кухни.
# - По графику видно линейную зависимость между ценой и параметрами площади.
# - Также в диаграмме рассеяния цены по количеству комнат к общей, жилой и площади \
# кухни наблюдаеться линейная зависимость.

# %%
# Зависимость от дня размещения
(
    data.pivot_table(index='weekday', values='last_price')
    .plot(grid=True, style='o-', figsize=(7, 5))
)
plt.show()
# Зависимость от месяца размещения
(
   data.pivot_table(index='month', values='last_price')
    .plot(grid=True, style='o-', xlim=(1,13), figsize=(15, 5))
)
plt.show()
# Зависимость от года размещения
(
    data.pivot_table(index='year', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# %% [markdown]
# ***Вывод:***
# - День недели: дороже всего квартиры, опубликованные в четверг, дешевле всего - в воскресенье.
# - Месяц: дороже всего квартиры, продающиеся с декабря, дешевле всего - с октября.
# - Год: с 2014 по 2016 года спад рынка, с 2016 по 2018 - минимумы, с 2018 по 2019 рост рынка недвижимости

# %%
(
   data.pivot_table(index='year', values='total_area', aggfunc='mean')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# %% [markdown]
# ***Вывод:***
# - Средняя площадь продаваемых квартир падала до 2018 года
# - С 2018 года площадь начала увеличиваться
# - Возможно подействовали программы льготной ипотеки от государства на новостройки.
# - Соответственно спрос возрос на бюджетное жилье, в ущерб площади.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Дело не в кризисе, дело в том, что на рынок вышел массовый продавец и средние показатели продаваемой квартиры снизились

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит перепроверить колебание цен после восстановления данных
#
# Можно посмотреть на среднюю площадь продаваемых квартир по годам

# %% [markdown]
# ### Нахождение средней цены одного квадратного метра в 10 населённых пунктах

# %%
# Сравниваем среднюю стоимость квадратного метра в топ-10 городов по числу объявлений
city_ten = data['locality_name'].value_counts().head(10)
city_sm_price = data.query('locality_name in (@city_ten.index)').pivot_table(values='price_one_metr', index='locality_name')
city_sm_price = city_sm_price.astype(int)
city_sm_price.sort_values('price_one_metr', ascending=False)
# Out:
#                    price_one_metr
# locality_name
# Санкт-Петербург            109782
# Пушкин                     101979
# деревня Кудрово             95432
# поселок Парголово           90123
# поселок Мурино              85899
# поселок Шушары              78443
# Колпино                     75097
# Гатчина                     68967
# Всеволожск                  68852
# Выборг                      58299

# %%
city_ten = data['locality_name'].value_counts().head(10)
def pass_value_barh(data):
    try:
        (city_sm_price
            .rename(columns = {0:'space'})
            .query('locality_name in (@city_ten.index)')
            .pivot_table(values='price_one_metr', index='locality_name')
            .sort_values('price_one_metr', ascending=False)
            .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Средняя цена 1 кв.метра в 10 населенных пунктах' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        pass

# %%
pass_value_barh(data)

# %% [markdown]
# ***Вывод:***
# - Наибольшая средняя стоимость квадратного метра, как и ожидалось, в Санкт-Петербурге.
# - Затем идёт Пушкин, что, вероятно, вызвано хорошей застройкой и большим количеством парков.
# - Затем идут районы, фактически являющиеся Санкт-Петербургом и непосредственно к нему примыкают.
# - Из топ-10 наименьшая стоимость в Кириши, из которого далеко ехать до Санкт-Петербурга,
# - А также неболшой по численности населения Выборг, расположенный на большом расстоянии от Санкт-Петербурга.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что применяешь код, за поворот текста отвечает параметр rot

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# ### Расчет средней цены каждого километра в Санкт-Петербурге и влияние стоимости объектов от расстояния до центра города.

# %%
# Добавляем столбец с расстоянием до центра в км, округляем до целого
data['center_km'] = data['cityCenters_nearest'] / 1000
data['center_km'] = data['center_km'].fillna(value=0).astype(int)
# Выбираем Санкт-Петербург, смотрим на график, где указана средняя стоимость для каждого км
(
    data.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='center_km', values='last_price')
    .plot(grid=True, style='o-', xlim=(0,15), figsize=(10, 5))
)
plt.show()

# %% [markdown]
# ***Вывод:***
# - Центральная зона - это 4 км и меньше.
# - Дальше 6 км средняя цена на квартиры резко снижается.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# ***Общий вывод***
# 1. Срок продажи квартиры
#
# - Чаще всего квартиру продают за 98 дней.
# - Если меньше 50 дней, то это быстро, если дольше 200 дней - это долго.
# - Есть большое число квартир, проданных всего за несколько дней после публикации.
# - Также есть варианты, которые продавались несколько десятков месяцев.
# 2. Факторы, влияющие на стоимость
#
# - На стоимость больше влияет площадь квартиры, нежели число комнат. Т.е. могут быть дорогие квартиры с малым числом комнат, но где комнаты просторные.
# - Первый и последний этажи значительно дешевле остальных вариантов.
# 3. Стоимость квадратного метра в топ-10 населённых пунктов
#
# - Дороже всего квадратный метр в Санкт-Петербурге - 114219
# - Дешевле всего квадратный метр в  Кириши - 38902

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
#
# Стоит поправить моменты после исправления комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнила исследовательскую работу, молодец, показала хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
# + проверить и вернуть пропуски в колонку о скорости продаж и о расстоянии до центра
# + проверить корректность заполнения пропусков синтетическими данными
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограммы и выводы в п.4.1
# + пересчитать скорость продаж
# + подправить графики, выводы и расчет коэф. корреляции  в п. 4.3
# + перепроверить итоговый вывод
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# ## Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='kitchen_area', alpha=0.5, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На примере ниже я покажу как фильтровать записи с пропусками
#
#
# Мягкие условия для удаления через логическую операцию или: оставляем все пропуски или все значения, которые ближе чем 60 000 метров
#
#         df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
#
# В изначальном датасете было всего записей — 23699 entries, из них заполненные
#
#             15  airports_nearest      18157 non-null  float64
#
# Осталось — 23525 entries, из них заполненные
#
#             15  airports_nearest      17983 non-null  float64
#
# т.е. все пропуски в столбце airports_nearest остались на месте
#
# Знак | обозначает логическую операцию «или», иногда мы ее записываем при помощи оператора «or»

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 
df_check.info()
df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример второго варианта фильтрации колонок с пропусками, в обновленной версии библиотеки пандас первый вариант работать, возможно, не будет

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 
df_check.info()
df_isna = df_check[(df_check ['airports_nearest'] < 60000) | (df_check ['airports_nearest'].isna()) ]

df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
